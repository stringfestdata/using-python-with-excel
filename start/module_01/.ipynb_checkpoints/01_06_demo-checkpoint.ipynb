# %%
# pip install vega_datasets

# %%
import pandas as pd
import seaborn as sns
from vega_datasets import local_data
import matplotlib.pyplot as plt

seattle = local_data.seattle_weather()
seattle.head()
# Out:
#         date  precipitation  temp_max  temp_min  wind  weather
# 0 2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1 2012-01-02           10.9      10.6       2.8   4.5     rain
# 2 2012-01-03            0.8      11.7       7.2   2.3     rain
# 3 2012-01-04           20.3      12.2       5.6   4.7     rain
# 4 2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
date = pd.to_datetime('8th sep, 2019 11:15 AM')
date
# Out:
# Timestamp('2019-09-08 11:15:00')

# %%
date.hour
# Out:
# 11

# %%
date.minute
# Out:
# 15

# %%
seattle.dtypes
# Out:
# date             datetime64[ns]
# precipitation           float64
# temp_max                float64
# temp_min                float64
# wind                    float64
# weather                  object
# dtype: object

# %%
seattle['month_name'] = seattle['date'].dt.month_name()
seattle['month_name'].head()
# Out:
# 0    January
# 1    January
# 2    January
# 3    January
# 4    January
# Name: month_name, dtype: object

# %%
seattle['date'].max()
# Out:
# Timestamp('2015-12-31 00:00:00')

# %%
seattle['date'].dt.to_period('M').max()
# Out:
# Period('2015-12', 'M')

# %%
type((seattle['date'].max() - seattle['date'].min()))
# Out:
# pandas._libs.tslibs.timedeltas.Timedelta

# %%
seattle.set_index(['date'], inplace=True)
seattle
# Out:
#             precipitation  temp_max  temp_min  wind  weather  month month_name
# date
# 2012-01-01            0.0      12.8       5.0   4.7  drizzle      1    January
# 2012-01-02           10.9      10.6       2.8   4.5     rain      1    January
# 2012-01-03            0.8      11.7       7.2   2.3     rain      1    January
# 2012-01-04           20.3      12.2       5.6   4.7     rain      1    January
# 2012-01-05            1.3       8.9       2.8   6.1     rain      1    January
# ...                   ...       ...       ...   ...      ...    ...        ...
# 2015-12-27            8.6       4.4       1.7   2.9      fog     12   December
# 2015-12-28            1.5       5.0       1.7   1.3      fog     12   December
# 2015-12-29            0.0       7.2       0.6   2.6      fog     12   December
# 2015-12-30            0.0       5.6      -1.0   3.4      sun     12   December
# 2015-12-31            0.0       5.6      -2.1   3.5      sun     12   December
#
# [1461 rows x 7 columns]

# %%
biweekly_precip = seattle['precipitation'].resample('W').mean()
biweekly_precip.head()

# %%
plt.figure(figsize = (15,8))
sns.lineplot(x=biweekly_precip.index, y=biweekly_precip.values, data=biweekly_precip)
# Out:
# <AxesSubplot:xlabel='date'>

# %%
low_temps_monthly = seattle['temp_min'].resample('M').min()
low_temps_monthly.head()
# Out:
# date
# 2012-01-31   -3.3
# 2012-02-29   -2.2
# 2012-03-31   -1.7
# 2012-04-30    1.7
# 2012-05-31    3.9
# Freq: M, Name: temp_min, dtype: float64

# %%
# Get the first of the month
# Get all the "Offset aliases" here: https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#offset-aliases
seattle['temp_max'].resample('MS').first()
# Out:
# date
# 2012-01-01    10.6
# 2012-02-01     8.9
# 2012-03-01     6.1
# 2012-04-01     8.9
# 2012-05-01    11.7
# 2012-06-01    20.0
# 2012-07-01    20.0
# 2012-08-01    23.9
# 2012-09-01    21.7
# 2012-10-01    23.3
# 2012-11-01    15.0
# 2012-12-01    13.3
# 2013-01-01     5.0
# 2013-02-01    11.7
# 2013-03-01    15.0
# 2013-04-01    17.2
# 2013-05-01    18.3
# 2013-06-01    22.8
# 2013-07-01    31.7
# 2013-08-01    20.6
# 2013-09-01    27.8
# 2013-10-01    14.4
# 2013-11-01    17.8
# 2013-12-01    13.3
# 2014-01-01     7.2
# 2014-02-01     7.8
# 2014-03-01     7.2
# 2014-04-01    14.4
# 2014-05-01    29.4
# 2014-06-01    22.2
# 2014-07-01    34.4
# 2014-08-01    28.9
# 2014-09-01    23.3
# 2014-10-01    18.3
# 2014-11-01    11.1
# 2014-12-01     4.4
# 2015-01-01     5.6
# 2015-02-01     9.4
# 2015-03-01    11.1
# 2015-04-01    12.8
# 2015-05-01    18.3
# 2015-06-01    16.1
# 2015-07-01    32.2
# 2015-08-01    33.3
# 2015-09-01    19.4
# 2015-10-01    21.1
# 2015-11-01    12.2
# 2015-12-01    10.0
# Freq: MS, Name: temp_max, dtype: float64

# %% [markdown]
# # Window functions

# %%
seattle['precip_lag'] = seattle['precipitation'].shift(1)
seattle.head()
# Out:
#             precipitation  temp_max  temp_min  wind  weather  month  \
# date
# 2012-01-01            0.0      12.8       5.0   4.7  drizzle      1
# 2012-01-02           10.9      10.6       2.8   4.5     rain      1
# 2012-01-03            0.8      11.7       7.2   2.3     rain      1
# 2012-01-04           20.3      12.2       5.6   4.7     rain      1
# 2012-01-05            1.3       8.9       2.8   6.1     rain      1
#
#            month_name  precip_lag
# date
# 2012-01-01    January         NaN
# 2012-01-02    January         0.0
# 2012-01-03    January        10.9
# 2012-01-04    January         0.8
# 2012-01-05    January        20.3

# %%
seattle['precip_lead'] = seattle['precipitation'].shift(-2)
seattle.head()
# Out:
#             precipitation  temp_max  temp_min  wind  weather  month  \
# date
# 2012-01-01            0.0      12.8       5.0   4.7  drizzle      1
# 2012-01-02           10.9      10.6       2.8   4.5     rain      1
# 2012-01-03            0.8      11.7       7.2   2.3     rain      1
# 2012-01-04           20.3      12.2       5.6   4.7     rain      1
# 2012-01-05            1.3       8.9       2.8   6.1     rain      1
#
#            month_name  precip_lag  precip_lead
# date
# 2012-01-01    January         NaN          0.8
# 2012-01-02    January         0.0         20.3
# 2012-01-03    January        10.9          1.3
# 2012-01-04    January         0.8          2.5
# 2012-01-05    January        20.3          0.0

# %%
seattle.count()
# Out:
# precipitation    1461
# temp_max         1461
# temp_min         1461
# wind             1461
# weather          1461
# month            1461
# month_name       1461
# precip_lag       1460
# precip_lead      1459
# dtype: int64

# %%
seattle.dropna(inplace=True)

# %%
seattle['precip_rolling_avg'] = seattle['precipitation'].rolling(7).mean()
seattle.head(14)
# Out:
#             precipitation  temp_max  temp_min  wind weather  month month_name  \
# date
# 2012-01-02           10.9      10.6       2.8   4.5    rain      1    January
# 2012-01-03            0.8      11.7       7.2   2.3    rain      1    January
# 2012-01-04           20.3      12.2       5.6   4.7    rain      1    January
# 2012-01-05            1.3       8.9       2.8   6.1    rain      1    January
# 2012-01-06            2.5       4.4       2.2   2.2    rain      1    January
# 2012-01-07            0.0       7.2       2.8   2.3    rain      1    January
# 2012-01-08            0.0      10.0       2.8   2.0     sun      1    January
# 2012-01-09            4.3       9.4       5.0   3.4    rain      1    January
# 2012-01-10            1.0       6.1       0.6   3.4    rain      1    January
# 2012-01-11            0.0       6.1      -1.1   5.1     sun      1    January
# 2012-01-12            0.0       6.1      -1.7   1.9     sun      1    January
# 2012-01-13            0.0       5.0      -2.8   1.3     sun      1    January
# 2012-01-14            4.1       4.4       0.6   5.3    snow      1    January
# 2012-01-15            5.3       1.1      -3.3   3.2    snow      1    January
#
#             precip_lag  precip_lead  precip_rolling_avg
# date
# 2012-01-02         0.0         20.3                 NaN
# 2012-01-03        10.9          1.3                 NaN
# 2012-01-04         0.8          2.5                 NaN
# 2012-01-05        20.3          0.0                 NaN
# 2012-01-06         1.3          0.0                 NaN
# 2012-01-07         2.5          4.3                 NaN
# 2012-01-08         0.0          1.0            5.114286
# 2012-01-09         0.0          0.0            4.171429
# 2012-01-10         4.3          0.0            4.200000
# 2012-01-11         1.0          0.0            1.300000
# 2012-01-12         0.0          4.1            1.114286
# 2012-01-13         0.0          5.3            0.757143
# 2012-01-14         0.0          2.5            1.342857
# 2012-01-15         4.1          8.1            2.100000

# %%
seattle['precip_rolling_sum'] = seattle['precipitation'].rolling(7).sum()
seattle.head(14)
# Out:
#             precipitation  temp_max  temp_min  wind weather  month month_name  \
# date
# 2012-01-02           10.9      10.6       2.8   4.5    rain      1    January
# 2012-01-03            0.8      11.7       7.2   2.3    rain      1    January
# 2012-01-04           20.3      12.2       5.6   4.7    rain      1    January
# 2012-01-05            1.3       8.9       2.8   6.1    rain      1    January
# 2012-01-06            2.5       4.4       2.2   2.2    rain      1    January
# 2012-01-07            0.0       7.2       2.8   2.3    rain      1    January
# 2012-01-08            0.0      10.0       2.8   2.0     sun      1    January
# 2012-01-09            4.3       9.4       5.0   3.4    rain      1    January
# 2012-01-10            1.0       6.1       0.6   3.4    rain      1    January
# 2012-01-11            0.0       6.1      -1.1   5.1     sun      1    January
# 2012-01-12            0.0       6.1      -1.7   1.9     sun      1    January
# 2012-01-13            0.0       5.0      -2.8   1.3     sun      1    January
# 2012-01-14            4.1       4.4       0.6   5.3    snow      1    January
# 2012-01-15            5.3       1.1      -3.3   3.2    snow      1    January
#
#             precip_lag  precip_lead  precip_rolling_avg  precip_rolling_sum
# date
# 2012-01-02         0.0         20.3                 NaN                 NaN
# 2012-01-03        10.9          1.3                 NaN                 NaN
# 2012-01-04         0.8          2.5                 NaN                 NaN
# 2012-01-05        20.3          0.0                 NaN                 NaN
# 2012-01-06         1.3          0.0                 NaN                 NaN
# 2012-01-07         2.5          4.3                 NaN                 NaN
# 2012-01-08         0.0          1.0            5.114286                35.8
# 2012-01-09         0.0          0.0            4.171429                29.2
# 2012-01-10         4.3          0.0            4.200000                29.4
# 2012-01-11         1.0          0.0            1.300000                 9.1
# 2012-01-12         0.0          4.1            1.114286                 7.8
# 2012-01-13         0.0          5.3            0.757143                 5.3
# 2012-01-14         0.0          2.5            1.342857                 9.4
# 2012-01-15         4.1          8.1            2.100000                14.7

# %%
seattle['precip_chg'] = seattle['precipitation'].pct_change(1)
seattle.head(14)
# Out:
#             precipitation  temp_max  temp_min  wind weather  month month_name  \
# date
# 2012-01-02           10.9      10.6       2.8   4.5    rain      1    January
# 2012-01-03            0.8      11.7       7.2   2.3    rain      1    January
# 2012-01-04           20.3      12.2       5.6   4.7    rain      1    January
# 2012-01-05            1.3       8.9       2.8   6.1    rain      1    January
# 2012-01-06            2.5       4.4       2.2   2.2    rain      1    January
# 2012-01-07            0.0       7.2       2.8   2.3    rain      1    January
# 2012-01-08            0.0      10.0       2.8   2.0     sun      1    January
# 2012-01-09            4.3       9.4       5.0   3.4    rain      1    January
# 2012-01-10            1.0       6.1       0.6   3.4    rain      1    January
# 2012-01-11            0.0       6.1      -1.1   5.1     sun      1    January
# 2012-01-12            0.0       6.1      -1.7   1.9     sun      1    January
# 2012-01-13            0.0       5.0      -2.8   1.3     sun      1    January
# 2012-01-14            4.1       4.4       0.6   5.3    snow      1    January
# 2012-01-15            5.3       1.1      -3.3   3.2    snow      1    January
#
#             precip_lag  precip_lead  precip_rolling_avg  precip_rolling_sum  \
# date
# 2012-01-02         0.0         20.3                 NaN                 NaN
# 2012-01-03        10.9          1.3                 NaN                 NaN
# 2012-01-04         0.8          2.5                 NaN                 NaN
# 2012-01-05        20.3          0.0                 NaN                 NaN
# 2012-01-06         1.3          0.0                 NaN                 NaN
# 2012-01-07         2.5          4.3                 NaN                 NaN
# 2012-01-08         0.0          1.0            5.114286                35.8
# 2012-01-09         0.0          0.0            4.171429                29.2
# 2012-01-10         4.3          0.0            4.200000                29.4
# 2012-01-11         1.0          0.0            1.300000                 9.1
# 2012-01-12         0.0          4.1            1.114286                 7.8
# 2012-01-13         0.0          5.3            0.757143                 5.3
# 2012-01-14         0.0          2.5            1.342857                 9.4
# 2012-01-15         4.1          8.1            2.100000                14.7
#
#             precip_chg
# date
# 2012-01-02         NaN
# 2012-01-03   -0.926606
# 2012-01-04   24.375000
# 2012-01-05   -0.935961
# 2012-01-06    0.923077
# 2012-01-07   -1.000000
# 2012-01-08         NaN
# 2012-01-09         inf
# 2012-01-10   -0.767442
# 2012-01-11   -1.000000
# 2012-01-12         NaN
# 2012-01-13         NaN
# 2012-01-14         inf
# 2012-01-15    0.292683

# %%
sns.lineplot(x='date', y='precip_rolling_avg', data=seattle)
# Out:
# <AxesSubplot:xlabel='date', ylabel='precip_rolling_avg'>

# %%
seattle['temp_max'].resample('MS').last().head()
# Out:
# date
# 2012-01-01     9.4
# 2012-02-01     5.0
# 2012-03-01    10.0
# 2012-04-01    12.8
# 2012-05-01    17.8
# Freq: MS, Name: temp_max, dtype: float64
