# %%
import pandas as pd
import seaborn as sns

tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_00d32">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00d32_level0_col0" class="col_heading level0 col0" >total_bill</th>
#       <th id="T_00d32_level0_col1" class="col_heading level0 col1" >tip</th>
#       <th id="T_00d32_level0_col2" class="col_heading level0 col2" >sex</th>
#       <th id="T_00d32_level0_col3" class="col_heading level0 col3" >smoker</th>
#       <th id="T_00d32_level0_col4" class="col_heading level0 col4" >day</th>
#       <th id="T_00d32_level0_col5" class="col_heading level0 col5" >time</th>
#       <th id="T_00d32_level0_col6" class="col_heading level0 col6" >size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00d32_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_00d32_row0_col0" class="data row0 col0" >16.990000</td>
#       <td id="T_00d32_row0_col1" class="data row0 col1" >1.010000</td>
#       <td id="T_00d32_row0_col2" class="data row0 col2" >Female</td>
#       <td id="T_00d32_row0_col3" class="data row0 col3" >No</td>
#       <td id="T_00d32_row0_col4" class="data row0 col4" >Sun</td>
#       <td id="T_00d32_row0_col5" class="data row0 col5" >Dinner</td>
#       <td id="T_00d32_row0_col6" class="data row0 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_00d32_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_00d32_row1_col0" class="data row1 col0" >10.340000</td>
#       <td id="T_00d32_row1_col1" class="data row1 col1" >1.660000</td>
#       <td id="T_00d32_row1_col2" class="data row1 col2" >Male</td>
#       <td id="T_00d32_row1_col3" class="data row1 col3" >No</td>
#       <td id="T_00d32_row1_col4" class="data row1 col4" >Sun</td>
#       <td id="T_00d32_row1_col5" class="data row1 col5" >Dinner</td>
#       <td id="T_00d32_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_00d32_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_00d32_row2_col0" class="data row2 col0" >21.010000</td>
#       <td id="T_00d32_row2_col1" class="data row2 col1" >3.500000</td>
#       <td id="T_00d32_row2_col2" class="data row2 col2" >Male</td>
#       <td id="T_00d32_row2_col3" class="data row2 col3" >No</td>
#       <td id="T_00d32_row2_col4" class="data row2 col4" >Sun</td>
#       <td id="T_00d32_row2_col5" class="data row2 col5" >Dinner</td>
#       <td id="T_00d32_row2_col6" class="data row2 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_00d32_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_00d32_row3_col0" class="data row3 col0" >23.680000</td>
#       <td id="T_00d32_row3_col1" class="data row3 col1" >3.310000</td>
#       <td id="T_00d32_row3_col2" class="data row3 col2" >Male</td>
#       <td id="T_00d32_row3_col3" class="data row3 col3" >No</td>
#       <td id="T_00d32_row3_col4" class="data row3 col4" >Sun</td>
#       <td id="T_00d32_row3_col5" class="data row3 col5" >Dinner</td>
#       <td id="T_00d32_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_00d32_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_00d32_row4_col0" class="data row4 col0" >24.590000</td>
#       <td id="T_00d32_row4_col1" class="data row4 col1" >3.610000</td>
#       <td id="T_00d32_row4_col2" class="data row4 col2" >Female</td>
#       <td id="T_00d32_row4_col3" class="data row4 col3" >No</td>
#       <td id="T_00d32_row4_col4" class="data row4 col4" >Sun</td>
#       <td id="T_00d32_row4_col5" class="data row4 col5" >Dinner</td>
#       <td id="T_00d32_row4_col6" class="data row4 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_00d32_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_00d32_row5_col0" class="data row5 col0" >25.290000</td>
#       <td id="T_00d32_row5_col1" class="data row5 col1" >4.710000</td>
#       <td id="T_00d32_row5_col2" class="data row5 col2" >Male</td>
#       <td id="T_00d32_row5_col3" class="data row5 col3" >No</td>
#       <td id="T_00d32_row5_col4" class="data row5 col4" >Sun</td>
#       <td id="T_00d32_row5_col5" class="data row5 col5" >Dinner</td>
#       <td id="T_00d32_row5_col6" class="data row5 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_00d32_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_00d32_row6_col0" class="data row6 col0" >8.770000</td>
#       <td id="T_00d32_row6_col1" class="data row6 col1" >2.000000</td>
#       <td id="T_00d32_row6_col2" class="data row6 col2" >Male</td>
#       <td id="T_00d32_row6_col3" class="data row6 col3" >No</td>
#       <td id="T_00d32_row6_col4" class="data row6 col4" >Sun</td>
#       <td id="T_00d32_row6_col5" class="data row6 col5" >Dinner</td>
#       <td id="T_00d32_row6_col6" class="data row6 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_00d32_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_00d32_row7_col0" class="data row7 col0" >26.880000</td>
#       <td id="T_00d32_row7_col1" class="data row7 col1" >3.120000</td>
#       <td id="T_00d32_row7_col2" class="data row7 col2" >Male</td>
#       <td id="T_00d32_row7_col3" class="data row7 col3" >No</td>
#       <td id="T_00d32_row7_col4" class="data row7 col4" >Sun</td>
#       <td id="T_00d32_row7_col5" class="data row7 col5" >Dinner</td>
#       <td id="T_00d32_row7_col6" class="data row7 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_00d32_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_00d32_row8_col0" class="data row8 col0" >15.040000</td>
#       <td id="T_00d32_row8_col1" class="data row8 col1" >1.960000</td>
#       <td id="T_00d32_row8_col2" class="data row8 col2" >Male</td>
#       <td id="T_00d32_row8_col3" class="data row8 col3" >No</td>
#       <td id="T_00d32_row8_col4" class="data row8 col4" >Sun</td>
#       <td id="T_00d32_row8_col5" class="data row8 col5" >Dinner</td>
#       <td id="T_00d32_row8_col6" class="data row8 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_00d32_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_00d32_row9_col0" class="data row9 col0" >14.780000</td>
#       <td id="T_00d32_row9_col1" class="data row9 col1" >3.230000</td>
#       <td id="T_00d32_row9_col2" class="data row9 col2" >Male</td>
#       <td id="T_00d32_row9_col3" class="data row9 col3" >No</td>
#       <td id="T_00d32_row9_col4" class="data row9 col4" >Sun</td>
#       <td id="T_00d32_row9_col5" class="data row9 col5" >Dinner</td>
#       <td id="T_00d32_row9_col6" class="data row9 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_00d32_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_00d32_row10_col0" class="data row10 col0" >10.270000</td>
#       <td id="T_00d32_row10_col1" class="data row10 col1" >1.710000</td>
#       <td id="T_00d32_row10_col2" class="data row10 col2" >Male</td>
#       <td id="T_00d32_row10_col3" class="data row10 col3" >No</td>
#       <td id="T_00d32_row10_col4" class="data row10 col4" >Sun</td>
#       <td id="T_00d32_row10_col5" class="data row10 col5" >Dinner</td>
#       <td id="T_00d32_row10_col6" class="data row10 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_00d32_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_00d32_row11_col0" class="data row11 col0" >35.260000</td>
#       <td id="T_00d32_row11_col1" class="data row11 col1" >5.000000</td>
#       <td id="T_00d32_row11_col2" class="data row11 col2" >Female</td>
#       <td id="T_00d32_row11_col3" class="data row11 col3" >No</td>
#       <td id="T_00d32_row11_col4" class="data row11 col4" >Sun</td>
#       <td id="T_00d32_row11_col5" class="data row11 col5" >Dinner</td>
#       <td id="T_00d32_row11_col6" class="data row11 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_00d32_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_00d32_row12_col0" class="data row12 col0" >15.420000</td>
#       <td id="T_00d32_row12_col1" class="data row12 col1" >1.570000</td>
#       <td id="T_00d32_row12_col2" class="data row12 col2" >Male</td>
#       <td id="T_00d32_row12_col3" class="data row12 col3" >No</td>
#       <td id="T_00d32_row12_col4" class="data row12 col4" >Sun</td>
#       <t

# %%
# Highlight all tips over 3 as green
def highlight_cells(val):
    color = 'green' if val > 3 else ''
    return 'background-color: {}'.format(color)

# How to apply to just one column???
tips.style.applymap(highlight_cells, subset=pd.IndexSlice[:, ['tip']])
# Out:
# <style type="text/css">
# #T_e8c3a_row0_col1, #T_e8c3a_row1_col1, #T_e8c3a_row6_col1, #T_e8c3a_row8_col1, #T_e8c3a_row10_col1, #T_e8c3a_row12_col1, #T_e8c3a_row13_col1, #T_e8c3a_row16_col1, #T_e8c3a_row21_col1, #T_e8c3a_row22_col1, #T_e8c3a_row25_col1, #T_e8c3a_row26_col1, #T_e8c3a_row27_col1, #T_e8c3a_row29_col1, #T_e8c3a_row30_col1, #T_e8c3a_row31_col1, #T_e8c3a_row32_col1, #T_e8c3a_row33_col1, #T_e8c3a_row36_col1, #T_e8c3a_row38_col1, #T_e8c3a_row40_col1, #T_e8c3a_row41_col1, #T_e8c3a_row43_col1, #T_e8c3a_row45_col1, #T_e8c3a_row48_col1, #T_e8c3a_row49_col1, #T_e8c3a_row50_col1, #T_e8c3a_row51_col1, #T_e8c3a_row53_col1, #T_e8c3a_row56_col1, #T_e8c3a_row57_col1, #T_e8c3a_row58_col1, #T_e8c3a_row61_col1, #T_e8c3a_row62_col1, #T_e8c3a_row64_col1, #T_e8c3a_row66_col1, #T_e8c3a_row67_col1, #T_e8c3a_row68_col1, #T_e8c3a_row69_col1, #T_e8c3a_row70_col1, #T_e8c3a_row71_col1, #T_e8c3a_row74_col1, #T_e8c3a_row75_col1, #T_e8c3a_row78_col1, #T_e8c3a_row79_col1, #T_e8c3a_row80_col1, #T_e8c3a_row82_col1, #T_e8c3a_row84_col1, #T_e8c3a_row86_col1, #T_e8c3a_row89_col1, #T_e8c3a_row90_col1, #T_e8c3a_row92_col1, #T_e8c3a_row97_col1, #T_e8c3a_row98_col1, #T_e8c3a_row99_col1, #T_e8c3a_row100_col1, #T_e8c3a_row101_col1, #T_e8c3a_row102_col1, #T_e8c3a_row105_col1, #T_e8c3a_row110_col1, #T_e8c3a_row111_col1, #T_e8c3a_row113_col1, #T_e8c3a_row117_col1, #T_e8c3a_row118_col1, #T_e8c3a_row119_col1, #T_e8c3a_row120_col1, #T_e8c3a_row121_col1, #T_e8c3a_row122_col1, #T_e8c3a_row123_col1, #T_e8c3a_row124_col1, #T_e8c3a_row126_col1, #T_e8c3a_row127_col1, #T_e8c3a_row128_col1, #T_e8c3a_row129_col1, #T_e8c3a_row130_col1, #T_e8c3a_row131_col1, #T_e8c3a_row132_col1, #T_e8c3a_row133_col1, #T_e8c3a_row135_col1, #T_e8c3a_row136_col1, #T_e8c3a_row137_col1, #T_e8c3a_row138_col1, #T_e8c3a_row139_col1, #T_e8c3a_row144_col1, #T_e8c3a_row145_col1, #T_e8c3a_row146_col1, #T_e8c3a_row147_col1, #T_e8c3a_row148_col1, #T_e8c3a_row149_col1, #T_e8c3a_row150_col1, #T_e8c3a_row151_col1, #T_e8c3a_row152_col1, #T_e8c3a_row153_col1, #T_e8c3a_row154_col1, #T_e8c3a_row158_col1, #T_e8c3a_row159_col1, #T_e8c3a_row161_col1, #T_e8c3a_row162_col1, #T_e8c3a_row163_col1, #T_e8c3a_row164_col1, #T_e8c3a_row166_col1, #T_e8c3a_row168_col1, #T_e8c3a_row169_col1, #T_e8c3a_row176_col1, #T_e8c3a_row177_col1, #T_e8c3a_row184_col1, #T_e8c3a_row187_col1, #T_e8c3a_row190_col1, #T_e8c3a_row192_col1, #T_e8c3a_row193_col1, #T_e8c3a_row195_col1, #T_e8c3a_row196_col1, #T_e8c3a_row198_col1, #T_e8c3a_row199_col1, #T_e8c3a_row201_col1, #T_e8c3a_row202_col1, #T_e8c3a_row203_col1, #T_e8c3a_row207_col1, #T_e8c3a_row208_col1, #T_e8c3a_row209_col1, #T_e8c3a_row210_col1, #T_e8c3a_row213_col1, #T_e8c3a_row215_col1, #T_e8c3a_row216_col1, #T_e8c3a_row217_col1, #T_e8c3a_row218_col1, #T_e8c3a_row220_col1, #T_e8c3a_row222_col1, #T_e8c3a_row223_col1, #T_e8c3a_row224_col1, #T_e8c3a_row225_col1, #T_e8c3a_row226_col1, #T_e8c3a_row227_col1, #T_e8c3a_row228_col1, #T_e8c3a_row229_col1, #T_e8c3a_row230_col1, #T_e8c3a_row231_col1, #T_e8c3a_row233_col1, #T_e8c3a_row234_col1, #T_e8c3a_row235_col1, #T_e8c3a_row236_col1, #T_e8c3a_row237_col1, #T_e8c3a_row240_col1, #T_e8c3a_row241_col1, #T_e8c3a_row242_col1, #T_e8c3a_row243_col1 {
#   background-color: ;
# }
# #T_e8c3a_row2_col1, #T_e8c3a_row3_col1, #T_e8c3a_row4_col1, #T_e8c3a_row5_col1, #T_e8c3a_row7_col1, #T_e8c3a_row9_col1, #T_e8c3a_row11_col1, #T_e8c3a_row14_col1, #T_e8c3a_row15_col1, #T_e8c3a_row17_col1, #T_e8c3a_row18_col1, #T_e8c3a_row19_col1, #T_e8c3a_row20_col1, #T_e8c3a_row23_col1, #T_e8c3a_row24_col1, #T_e8c3a_row28_col1, #T_e8c3a_row34_col1, #T_e8c3a_row35_col1, #T_e8c3a_row37_col1, #T_e8c3a_row39_col1, #T_e8c3a_row42_col1, #T_e8c3a_row44_col1, #T_e8c3a_row46_col1, #T_e8c3a_row47_col1, #T_e8c3a_row52_col1, #T_e8c3a_row54_col1, #T_e8c3a_row55_col1, #T_e8c3a_row59_col1, #T_e8c3a_row60_col1, #T_e8c3a_row63_col1, #T_e8c3a_row65_col1, #T_e8c3a_row72_col1, #T_e8c3a_row73_col1, #T_e8c3a_row76_col1, #T_e8c3a_row77_col1, #T_e8c3a_row81_col1, #T_e8c3a_row83_col1, #T_e8c3a_row85_col1, #T_e8c3a_row87_col1, #T_e8c3a_row88_col1, #T_e8c3a_row91_col1, #T_e8c3a_row93_col1, #T_e8c3a_row94_col1, #T_e8c3a_row95_col1, #T_e8c3a_row96_col1, #T_e8c3a_row103_col1, #T_e8c3a_row104_col1, #T_e8c3a_row106_col1, #T_e8c3a_row107_col1, #T_e8c3a_row108_col1, #T_e8c3a_row109_col1, #T_e8c3a_row112_col1, #T_e8c3a_row114_col1, #T_e8c3a_row115_col1, #T_e8c3a_row116_col1, #T_e8c3a_row125_col1, #T_e8c3a_row134_col1, #T_e8c3a_row140_col1, #T_e8c3a_row141_col1, #T_e8c3a_row142_col1, #T_e8c3a_row143_col1, #T_e8c3a_row155_col1, #T_e8c3a_row156_col1, #T_e8c3a_row157_col1, #T_e8c3a_row160_col1, #T_e8c3a_row165_col1, #T_e8c3a_row167_col1, #T_e8c3a_row170_col1, #T_e8c3a_row171_col1, #T_e8c3a_row172_col1, #T_e8c3a_row173_col1, #T_e8c3a_row174_col1, #T_e8c3a_row175_col1, #T_e8c3a_row178_col1, #T_e8c3a_row179_col1, #T_e8c3a_row180_col1, #T_e8c3a_row181_col1, #T_e8c3a_row182_col1, #T_e8c3a_row183_col1, #T_e8c3a_row185_col1, #T_e8c3a_row186_col1, #T_e8c3a_row188_col1, #T_e8c3a_row189_col1, #T_e8c3a_row191_col1, #T_e8c3a_row194_col1, #T_e8c3a_row197_col1, #T_e8c3a_row200_col1, #T_e8c3a_row204_col1, #T_e8c3a_row205_col1, #T_e8c3a_row206_col1, #T_e8c3a_row211_col1, #T_e8c3a_row212_col1, #T_e8c3a_row214_col1, #T_e8c3a_row219_col1, #T_e8c3a_row221_col1, #T_e8c3a_row232_col1, #T_e8c3a_row238_col1, #T_e8c3a_row239_col1 {
#   background-color: green;
# }
# </style>
# <table id="T_e8c3a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8c3a_level0_col0" class="col_heading level0 col0" >total_bill</th>
#       <th id="T_e8c3a_level0_col1" class="col_heading level0 col1" >tip</th>
#       <th id="T_e8c3a_level0_col2" class="col_heading level0 col2" >sex</th>
#       <th id="T_e8c3a_level0_col3" class="col_heading level0 col3" >smoker</th>
#       <th id="T_e8c3a_level0_col4" class="col_heading level0 col4" >day</th>
#       <th id="T_e8c3a_level0_col5" class="col_heading level0 col5" >time</th>
#       <th id="T_e8c3a_level0_col6" class="col_heading level0 col6" >size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8c3a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e8c3a_row0_col0" class="data row0 col0" >16.990000</td>
#       <td id="T_e8c3a_row0_col1" class="data row0 col1" >1.010000</td>
#       <td id="T_e8c3a_row0_col2" class="data row0 col2" >Female</td>
#       <td id="T_e8c3a_row0_col3" class="data row0 col3" >No</td>
#       <td id="T_e8c3a_row0_col4" class="data row0 col4" >Sun</td>
#       <td id="T_e8c3a_row0_col5" class="data row0 col5" >Dinner</td>
#       <td id="T_e8c3a_row0_col6" class="data row0 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_e8c3a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e8c3a_row1_col0" class="data row1 col0" >10.340000</td>
#       <td id="T_e8c3a_row1_col1" class="data row1 col1" >1.660000</td>
#       <td id="T_e8c3a_row1_col2" class="data row1 col2" >Male</td>
#       <td id="T_e8c3a_row1_col3" class="data row1 col3" >No</td>
#       <td id="T_e8c3a_row1_col4" class="data row1 col4" >Sun</td>
#       <td id="T_e8c3a_row1_col5" class="data row1 col5" >Dinner</td>
#       <td id="T_e8c3a_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_e8c3a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e8c3a_row2_col0" class="data row2 col0" >21.010000</td>
#       <td id="T_e8c3a_row2_col1" class="data row2 col1" >3.500000</td>
#       <td id="T_e8c3a_row2_col2" class="data row2 col2" >Male</td>
#       <td id="T_e8c3a_row2_col3" class="data row2 col3" >No</td>
#       <td id="T_e8c3a_row2_col4" class="data row2 col4" >Sun</td>
#       <td id="T_e8c3a_row2_col5" class="data row2 col5" >Dinner</td>
#       <td id="T_e8c3a_row2_col6" class="data row2 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_e8c3a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e8c3a_row3_col0" class="data row3 col0" >23.680000</td>
#       <td id="T_e8c3a_row3_col1" class="data row3 col1" >3.310000</td>
#       <td id="T_e8c3a_row3_col2" class="data row3 col2"

# %%
# Highlight the entire row as green if over 5, yellow if over 3, nothing if else
def highlight_rows(row):
    value = row.loc['tip']
    if value > 5:
        color = '#90EE90' # Green
    elif value > 3:
        color = '#ffffe0' # Yellow
    else:
        color = '#fffff' # Blank
    return ['background-color: {}'.format(color) for r in row]

tips.style.apply(highlight_rows, axis=1)
# Out:
# <style type="text/css">
# #T_7b4bd_row0_col0, #T_7b4bd_row0_col1, #T_7b4bd_row0_col2, #T_7b4bd_row0_col3, #T_7b4bd_row0_col4, #T_7b4bd_row0_col5, #T_7b4bd_row0_col6, #T_7b4bd_row1_col0, #T_7b4bd_row1_col1, #T_7b4bd_row1_col2, #T_7b4bd_row1_col3, #T_7b4bd_row1_col4, #T_7b4bd_row1_col5, #T_7b4bd_row1_col6, #T_7b4bd_row6_col0, #T_7b4bd_row6_col1, #T_7b4bd_row6_col2, #T_7b4bd_row6_col3, #T_7b4bd_row6_col4, #T_7b4bd_row6_col5, #T_7b4bd_row6_col6, #T_7b4bd_row8_col0, #T_7b4bd_row8_col1, #T_7b4bd_row8_col2, #T_7b4bd_row8_col3, #T_7b4bd_row8_col4, #T_7b4bd_row8_col5, #T_7b4bd_row8_col6, #T_7b4bd_row10_col0, #T_7b4bd_row10_col1, #T_7b4bd_row10_col2, #T_7b4bd_row10_col3, #T_7b4bd_row10_col4, #T_7b4bd_row10_col5, #T_7b4bd_row10_col6, #T_7b4bd_row12_col0, #T_7b4bd_row12_col1, #T_7b4bd_row12_col2, #T_7b4bd_row12_col3, #T_7b4bd_row12_col4, #T_7b4bd_row12_col5, #T_7b4bd_row12_col6, #T_7b4bd_row13_col0, #T_7b4bd_row13_col1, #T_7b4bd_row13_col2, #T_7b4bd_row13_col3, #T_7b4bd_row13_col4, #T_7b4bd_row13_col5, #T_7b4bd_row13_col6, #T_7b4bd_row16_col0, #T_7b4bd_row16_col1, #T_7b4bd_row16_col2, #T_7b4bd_row16_col3, #T_7b4bd_row16_col4, #T_7b4bd_row16_col5, #T_7b4bd_row16_col6, #T_7b4bd_row21_col0, #T_7b4bd_row21_col1, #T_7b4bd_row21_col2, #T_7b4bd_row21_col3, #T_7b4bd_row21_col4, #T_7b4bd_row21_col5, #T_7b4bd_row21_col6, #T_7b4bd_row22_col0, #T_7b4bd_row22_col1, #T_7b4bd_row22_col2, #T_7b4bd_row22_col3, #T_7b4bd_row22_col4, #T_7b4bd_row22_col5, #T_7b4bd_row22_col6, #T_7b4bd_row25_col0, #T_7b4bd_row25_col1, #T_7b4bd_row25_col2, #T_7b4bd_row25_col3, #T_7b4bd_row25_col4, #T_7b4bd_row25_col5, #T_7b4bd_row25_col6, #T_7b4bd_row26_col0, #T_7b4bd_row26_col1, #T_7b4bd_row26_col2, #T_7b4bd_row26_col3, #T_7b4bd_row26_col4, #T_7b4bd_row26_col5, #T_7b4bd_row26_col6, #T_7b4bd_row27_col0, #T_7b4bd_row27_col1, #T_7b4bd_row27_col2, #T_7b4bd_row27_col3, #T_7b4bd_row27_col4, #T_7b4bd_row27_col5, #T_7b4bd_row27_col6, #T_7b4bd_row29_col0, #T_7b4bd_row29_col1, #T_7b4bd_row29_col2, #T_7b4bd_row29_col3, #T_7b4bd_row29_col4, #T_7b4bd_row29_col5, #T_7b4bd_row29_col6, #T_7b4bd_row30_col0, #T_7b4bd_row30_col1, #T_7b4bd_row30_col2, #T_7b4bd_row30_col3, #T_7b4bd_row30_col4, #T_7b4bd_row30_col5, #T_7b4bd_row30_col6, #T_7b4bd_row31_col0, #T_7b4bd_row31_col1, #T_7b4bd_row31_col2, #T_7b4bd_row31_col3, #T_7b4bd_row31_col4, #T_7b4bd_row31_col5, #T_7b4bd_row31_col6, #T_7b4bd_row32_col0, #T_7b4bd_row32_col1, #T_7b4bd_row32_col2, #T_7b4bd_row32_col3, #T_7b4bd_row32_col4, #T_7b4bd_row32_col5, #T_7b4bd_row32_col6, #T_7b4bd_row33_col0, #T_7b4bd_row33_col1, #T_7b4bd_row33_col2, #T_7b4bd_row33_col3, #T_7b4bd_row33_col4, #T_7b4bd_row33_col5, #T_7b4bd_row33_col6, #T_7b4bd_row36_col0, #T_7b4bd_row36_col1, #T_7b4bd_row36_col2, #T_7b4bd_row36_col3, #T_7b4bd_row36_col4, #T_7b4bd_row36_col5, #T_7b4bd_row36_col6, #T_7b4bd_row38_col0, #T_7b4bd_row38_col1, #T_7b4bd_row38_col2, #T_7b4bd_row38_col3, #T_7b4bd_row38_col4, #T_7b4bd_row38_col5, #T_7b4bd_row38_col6, #T_7b4bd_row40_col0, #T_7b4bd_row40_col1, #T_7b4bd_row40_col2, #T_7b4bd_row40_col3, #T_7b4bd_row40_col4, #T_7b4bd_row40_col5, #T_7b4bd_row40_col6, #T_7b4bd_row41_col0, #T_7b4bd_row41_col1, #T_7b4bd_row41_col2, #T_7b4bd_row41_col3, #T_7b4bd_row41_col4, #T_7b4bd_row41_col5, #T_7b4bd_row41_col6, #T_7b4bd_row43_col0, #T_7b4bd_row43_col1, #T_7b4bd_row43_col2, #T_7b4bd_row43_col3, #T_7b4bd_row43_col4, #T_7b4bd_row43_col5, #T_7b4bd_row43_col6, #T_7b4bd_row45_col0, #T_7b4bd_row45_col1, #T_7b4bd_row45_col2, #T_7b4bd_row45_col3, #T_7b4bd_row45_col4, #T_7b4bd_row45_col5, #T_7b4bd_row45_col6, #T_7b4bd_row48_col0, #T_7b4bd_row48_col1, #T_7b4bd_row48_col2, #T_7b4bd_row48_col3, #T_7b4bd_row48_col4, #T_7b4bd_row48_col5, #T_7b4bd_row48_col6, #T_7b4bd_row49_col0, #T_7b4bd_row49_col1, #T_7b4bd_row49_col2, #T_7b4bd_row49_col3, #T_7b4bd_row49_col4, #T_7b4bd_row49_col5, #T_7b4bd_row49_col6, #T_7b4bd_row50_col0, #T_7b4bd_row50_col1, #T_7b4bd_row50_col2, #T_7b4bd_row50_col3, #T_7b4bd_row50_col4, #T_7b4bd_row50_col5, #T_7b4bd_row50_col6, #T_7b4bd_row51_col0, #T_7b4bd_row51_col1, #T_7b4bd_row51_co ...

# %%
tips.style.apply(highlight_rows, axis=1).to_excel('styled_tips.xlsx', engine='openpyxl',
                                                 index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 tips.style.apply(highlight_rows, axis=1).to_excel('styled_tips.xlsx', engine='openpyxl',
#       2                                                  index=False)
#
# File ~\anaconda3\lib\site-packages\pandas\io\formats\style.py:480, in Styler.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#     467 from pandas.io.formats.excel import ExcelFormatter
#     469 formatter = ExcelFormatter(
#     470     self,
#     471     na_rep=na_rep,
#    (...)
#     478     inf_rep=inf_rep,
#     479 )
# --> 480 formatter.write(
#     481     excel_writer,
#     482     sheet_name=sheet_name,
#     483     startrow=startrow,
#     484     startcol=startcol,
#     485     freeze_panes=freeze_panes,
#     486     engine=engine,
#     487 )
#
# File ~\anaconda3\lib\site-packages\pandas\io\formats\excel.py:894, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     891     need_save = True
#     893 try:
# --> 894     writer.write_cells(
#     895         formatted_cells,
#     896         sheet_name,
#     897         startrow=startrow,
#     898         startcol=startcol,
#     899         freeze_panes=freeze_panes,
#     900     )
#     901 finally:
#     902     # make sure to close opened file handles
#     903     if need_save:
#
# File ~\anaconda3\lib\site-packages\pandas\io\excel\_openpyxl.py:460, in OpenpyxlWriter.write_cells(self, cells, sheet_name, startrow, startcol, freeze_panes)
#     455 if validate_freeze_panes(freeze_panes):
#     456     wks.freeze_panes = wks.cell(
#     457         row=freeze_panes[0] + 1, column=freeze_panes[1] + 1
#     458     )
# --> 460 for cell in cells:
#     461     xcell = wks.cell(
#     462         row=startrow + cell.row + 1, column=startcol + cell.col + 1
#     463     )
#     464     xcell.value, fmt = self._value_with_fmt(cell.val)
#
# File ~\anaconda3\lib\site-packages\pandas\io\formats\excel.py:831, in ExcelFormatter.get_formatted_cells(self)
#     830 def get_formatted_cells(self) -> Iterable[ExcelCell]:
# --> 831     for cell in itertools.chain(self._format_header(), self._format_body()):
#     832         cell.val = self._format_value(cell.val)
#     833         yield cell
#
# File ~\anaconda3\lib\site-packages\pandas\io\formats\excel.py:726, in ExcelFormatter._format_regular_rows(self)
#     723 else:
#     724     coloffset = 0
# --> 726 yield from self._generate_body(coloffset)
#
# File ~\anaconda3\lib\site-packages\pandas\io\formats\excel.py:819, in ExcelFormatter._generate_body(self, coloffset)
#     817 series = self.df.iloc[:, colidx]
#     818 for i, val in enumerate(series):
# --> 819     yield CssExcelCell(
#     820         row=self.rowcounter + i,
#     821         col=colidx + coloffset,
#     822         val=val,
#     823         style=None,
#     824         css_styles=getattr(self.styler, "ctx", None),
#     825         css_row=i,
#     826         css_col=colidx,
#     827         css_converter=self.style_converter,
#     828     )
#
# File ~\anaconda3\lib\site-packages\pandas\io\formats\excel.py:91, in CssExcelCell.__init__(self, row, col, val, style, css_styles, css_row, css_col, css_converter, **kwargs)
#      87 if css_styles and css_converter:
#      88     css = ";".join(
#      89         [a + ":" + str(v) for (a, v) in css_styles[css_row, css_col]]
#      90     )
# ---> 91     style = css_converter(css)
#      93 return super().__init__(row=row, col=col, val=val, style=style, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\formats\excel.py:187, in CSSToExcelConverter.__call__(self, declarations_str)
#     185 # TODO: memoize?
#     186 properties = self.compute_css(declarations_str, self.inherited)
# --> 187 return self.build_xlstyle(properties)
#
# File ~\anaconda3\lib\site-packages\pandas\io\formats\excel.py:193, in CSSToExcelConverter.build_xlstyle(self, props)
#     189 def build_xlstyle(self, props: Mapping[str, str]) -> dict[str, dict[str, str]]:
#     190     out = {
#     191         "alignment": self.build_alignment(props),
#     192         "border": self.build_border(props),
# --> 193         "fill": self.build_fill(props),
#     194         "font": self.build_font(props),
#     195         "number_format": self.build_number_format(props),
#     196     }
#     198     # TODO: handle cell width and height: needs support in pandas.io.excel
#     200     def remove_none(d: dict[str, str]) -> None:
#
# File ~\anaconda3\lib\site-packages\pandas\io\formats\excel.py:309, in CSSToExcelConverter.build_fill(self, props)
#     307 fill_color = props.get("background-color")
#     308 if fill_color not in (None, "transparent", "none"):
# --> 309     return {"fgColor": self.color_to_excel(fill_color), "patternType": "solid"}
#
# File ~\anaconda3\lib\site-packages\pandas\io\formats\excel.py:409, in CSSToExcelConverter.color_to_excel(self, val)
#     406     return None
#     408 if self._is_hex_color(val):
# --> 409     return self._convert_hex_to_excel(val)
#     411 try:
#     412     return self.NAMED_COLORS[val]
#
# File ~\anaconda3\lib\site-packages\pandas\io\formats\excel.py:422, in CSSToExcelConverter._convert_hex_to_excel(self, color_string)
#     420 def _convert_hex_to_excel(self, color_string: str) -> str:
#     421     code = color_string.lstrip("#")
# --> 422     if self._is_shorthand_color(color_string):
#     423         return (code[0] * 2 + code[1] * 2 + code[2] * 2).upper()
#     424     else:
#
# File ~\anaconda3\lib\site-packages\pandas\io\formats\excel.py:438, in CSSToExcelConverter._is_shorthand_color(self, color_string)
#     436     return False
#     437 else:
# --> 438     raise ValueError(f"Unexpected color {color_string}")
#
# ValueError: Unexpected color #fffff
